# %% [markdown]
# ## TASK 4

# %% [markdown]
# ## RED WINE QUALITY

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset

# %%
wine = pd.read_csv(r"C:\Users\$hadow\Downloads\archive (3)\winequality-red.csv")

# %% [markdown]
# ## Shape of dataset

# %%
wine.shape
# Out:
# (1599, 12)

# %% [markdown]
# ## Dataset info

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## Dataset

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## Changing datatype of column

# %%
wine["quality"] = wine["quality"].astype(object)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 150.0+ KB

# %% [markdown]
# ## discrete univariate analysis

# %%
def discrete_univariate_analysis(discrete_data):
    for col_name in discrete_data:
        print("*"*10, col_name, "*"*10)
        print(discrete_data[col_name].agg(["count","nunique","unique"]))
        print("Value Counts: \n", discrete_data[col_name].value_counts())
        print()

# %%
discrete_df = wine.select_dtypes(include=["object"])
discrete_univariate_analysis(discrete_df)
# Out:
# ********** quality **********
# count                    1599
# nunique                     6
# unique     [5, 6, 7, 4, 8, 3]
# Name: quality, dtype: object
# Value Counts:
#  quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %% [markdown]
# ## numerical univariate analysis

# %%
def numerical_univariate_analysis(numerical_data):
    for col_name in numerical_data:
        print("*"*10, col_name, "*"*10)
        print(numerical_data[col_name].agg(["min","max","mean","median","count","std","skew"]))
        print()

# %%
numerical_df = wine.select_dtypes(include=["float64","int64"])
numerical_univariate_analysis(numerical_df)
# Out:
# ********** fixed acidity **********
# min          4.600000
# max         15.900000
# mean         8.319637
# median       7.900000
# count     1599.000000
# std          1.741096
# skew         0.982751
# Name: fixed acidity, dtype: float64
#
# ********** volatile acidity **********
# min          0.120000
# max          1.580000
# mean         0.527821
# median       0.520000
# count     1599.000000
# std          0.179060
# skew         0.671593
# Name: volatile acidity, dtype: float64
#
# ********** citric acid **********
# min          0.000000
# max          1.000000
# mean         0.270976
# median       0.260000
# count     1599.000000
# std          0.194801
# skew         0.318337
# Name: citric acid, dtype: float64
#
# ********** residual sugar **********
# min          0.900000
# max         15.500000
# mean         2.538806
# median       2.200000
# count     1599.000000
# std          1.409928
# skew         4.540655
# Name: residual sugar, dtype: float64
#
# ...

# %% [markdown]
# ## Visual analysis

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(wine.select_dtypes(include=["float64"]).corr(),annot=True,linewidth=0.5)
# Out:
# <Axes: >

# %%
sns.boxplot(data=wine,x="quality",y="fixed acidity")
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
sns.boxplot(data=wine,x="quality",y="volatile acidity")
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.boxplot(data=wine,x="quality",y="pH")
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
sns.countplot(data = wine,x="quality")
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sns.boxplot(data=wine,x="quality",y="density")
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
sns.scatterplot(data=wine,y="residual sugar",x="density")
# Out:
# <Axes: xlabel='density', ylabel='residual sugar'>

# %%
sns.boxplot(data=wine,x="quality",y="residual sugar")
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
crossbar = pd.crosstab(wine["quality"],wine["quality"],normalize="index")
crossbar.plot(kind="barh",stacked = True)
# Out:
# <Axes: ylabel='quality'>
